# %% [markdown]
# # Spotify Playlist Prediction
# **Kevin Yoon, Madeleine Nakada, Michelle Xie**

# %%
import pandas as pd
import json
import random
from sklearn.model_selection import train_test_split
from collections import Counter
import requests
import pprint

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
#from spotify import get_features

# %%
base_url = "https://api.spotify.com/v1"
token = "BQCKQpjFThCP9CEfPFrgu-g59An7CdxFyEeskv92wptcAxn2NC0aVfALHna10pvFMFTli_YHjfiQ3QRbOhQ"
headers = {'Authorization': 'Bearer ' + token}


def get_features(songs):
    url = base_url + '/audio-features'
    payload = {'ids': ','.join(songs)}
    r =requests.get(url, headers=headers, params=payload)
    data = r.json()
    return data["audio_features"]

# %%
# add some code here to randomize selection

# %%
path = './mpd.slice.0-999.json'

with open(path) as infile:
    data = json.load(infile)
playlists = pd.DataFrame(data['playlists'])
playlists.set_index("pid")
playlists.shape
# print(data.keys())
# print(len(data['playlists']))
# print(data['playlists'][0])
# pd.DataFrame.from_dict(data)
# print(data)
# data = json.loads('./data/mpd.slice.0-999.json')
# Out:
# (1000, 12)

# %%
features = ["acousticness", "danceability","duration_ms",
            "energy","instrumentalness","key","liveness",
            "loudness","mode","speechiness","time_signature",
            "tempo","valence"]
for feature in features:
    playlists[feature] = None

# %%
playlists.head()
# Out:
#   collaborative description duration_ms  modified_at              name  \
# 0         false         NaN        None   1493424000        Throwbacks
# 1         false         NaN        None   1506556800  Awesome Playlist
# 2         false         NaN        None   1505692800           korean
# 3         false         NaN        None   1501027200               mat
# 4         false         NaN        None   1401667200               90s
#
#    num_albums  num_artists  num_edits  num_followers  num_tracks   ...    \
# 0          47           37          6              1          52   ...
# 1          23           21          5              1          39   ...
# 2          51           31         18              1          64   ...
# 3         107           86          4              1         126   ...
# 4          16           16          7              2          17   ...
#
#    energy instrumentalness   key liveness loudness  mode speechiness  \
# 0    None             None  None     None     None  None        None
# 1    None             None  None     None     None  None        None
# 2    None             None  None     None     None  None        None
# 3    None             None  None     None     None  None        None
# 4    None             None  None     None     None  None        None
#
#   time_signature tempo valence
# 0           None  None    None
# 1           None  None    None
# 2           None  None    None
# 3           None  None    None
# 4           None  None    None
#
# [5 rows x 24 columns]

# %%
for index, row in playlists.iterrows():
    features = {
        "acousticness": 0,
        "danceability": 0,
        "duration_ms" : 0,
        "energy" : 0,
        "instrumentalness" : 0,
        "key" : 0,
        "liveness" : 0,
        "loudness" : 0,
        "mode" : 0,
        "speechiness" : 0,
        "time_signature" : 0,
        "tempo" : 0,
        "valence" : 0,
    }
    artists = Counter()
    genres = Counter()
    all_features = set(features.keys())
    tracks = row["tracks"]
    songs = []
    counters = set(["artists", "genres"])
    for track in tracks:                
        track_id = track['track_uri'].split(":")[-1]
        songs.append(track_id)
        artists[track['artist_uri']] += 1
    try:
        song_data = get_features(songs)
    except:
        print("Failed on row %d", index)
    for song in song_data:
        for feature in all_features:
            if feature in counters:
                features[song[feature]] += 1
            else:
                features[feature] += song[feature]
    for feature in all_features:
        if feature in counters:
            continue
        else:
            features[feature] = features[feature] / float(row["num_tracks"])
            if feature == "time_signature":
                features[feature] = int(features[feature] + 0.5)
            playlists.at[index, feature] = features[feature]
#     print(features)
# Out:
#   File "<ipython-input-11-64f553c5a275>", line 18
#     "artists" = Counter()
#     ^
# SyntaxError: can't assign to literal

# %%
playlists.head()
# Out:
#   collaborative description duration_ms  modified_at              name  \
# 0         false         NaN      221777   1493424000        Throwbacks
# 1         false         NaN      298844   1506556800  Awesome Playlist
# 2         false         NaN      219375   1505692800           korean
# 3         false         NaN        None   1501027200               mat
# 4         false         NaN        None   1401667200               90s
#
#    num_albums  num_artists  num_edits  num_followers  num_tracks    ...     \
# 0          47           37          6              1          52    ...
# 1          23           21          5              1          39    ...
# 2          51           31         18              1          64    ...
# 3         107           86          4              1         126    ...
# 4          16           16          7              2          17    ...
#
#      energy instrumentalness      key  liveness loudness      mode  \
# 0  0.782173       0.00067601  5.03846  0.192127 -4.88194  0.692308
# 1  0.691077          0.22227  4.46154  0.178433 -8.29167  0.538462
# 2  0.693203      0.000637814        5  0.169028 -4.87416  0.515625
# 3      None             None     None      None     None      None
# 4      None             None     None      None     None      None
#
#   speechiness time_signature    tempo   valence
# 0    0.107021              4  123.007  0.642904
# 1   0.0884487              4   122.67  0.476667
# 2   0.0962875              4  114.601  0.565078
# 3        None           None     None      None
# 4        None           None     None      None
#
# [5 rows x 24 columns]

# %%
train_data, test_data = train_test_split(playlists, test_size=0.2, random_state=42)

# %%
train_data.shape, test_data.shape
# Out:
# ((800, 12), (200, 12))

# %%
train_data.head()
# Out:
#     collaborative description  duration_ms  modified_at     name  num_albums  \
# 29          false         NaN      8059613   1506384000   groovy          39
# 535         false         NaN     12714068   1359244800  halcyon          11
# 695         false         NaN      4444821   1415577600    three          17
# 557         false         NaN     16177296   1508803200     Work          68
# 836         false         NaN      3999213   1506470400   boujee          17
#
#      num_artists  num_edits  num_followers  num_tracks  pid  \
# 29            39         16              1          40   29
# 535            3          5              4          46  535
# 695           19          4              1          20  695
# 557           59         14              1          70  557
# 836           16          2              1          19  836
#
#                                                 tracks
# 29   [{'pos': 0, 'artist_name': 'Lauv', 'track_uri'...
# 535  [{'pos': 0, 'artist_name': 'Ellie Goulding', '...
# 695  [{'pos': 0, 'artist_name': 'Chorus - Hercules'...
# 557  [{'pos': 0, 'artist_name': 'Lil Wyte', 'track_...
# 836  [{'pos': 0, 'artist_name': 'A$AP Ferg', 'track...
